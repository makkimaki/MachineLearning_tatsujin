# %% [markdown]
# <a href="https://colab.research.google.com/github/makkimaki/MachineLearning_tatsujin/blob/master/stable_diffusion_keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras-cv
# !pip install --upgrade tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import keras_cv
import matplotlib.pyplot as plt

# %%
model = keras_cv.models.StableDiffusion(img_width=256, img_height=256)
# Out:
# ...
# 198180272/198180272 [==============================] - 3s 0us/step

# %%
def plot_images(image):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i+1)
        plt.imshow(images[i])
        plt.axis("off")

# %%
images = model.text_to_image("Einstein and Godzilla drinking tea together at a round table.",
                                batch_size=5)

plot_images(images)
# Out:
# 25/25 [==============================] - 919s 36s/step

# %%
images = model.text_to_image("Einstein and Godzilla drinking tea together at a round table."
                                "concept art, character concepts, digital painting, mystery, adventure",
                                batch_size=5)

plot_images(images)
# Out:
# 25/25 [==============================] - 945s 37s/step
